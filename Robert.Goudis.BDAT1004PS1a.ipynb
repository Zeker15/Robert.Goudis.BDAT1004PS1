// %% [markdown]
// Question 1. C#

// %%
int myNum = 5;
                Console.WriteLine(myNum);
// Out:
// 5

// %%
double myNum = 5.0D;
    Console.WriteLine(myNum);
// Out:
// 5

// %%
int x = 5;
int y = 1;

    Console.WriteLine(5 > 1);
// Out:
// True

// %%
char myNum = '5';
    Console.WriteLine(myNum);
// Out:
// 5

// %%
int x = 5;
int y = 2;

    Console.WriteLine(5 * 2);
// Out:
// 10

// %% [markdown]
// Question 2. C#

// %%
string txt = "Supercalifragilisticexpialidocious";

    Console.WriteLine(txt.Length);
// Out:
// 34

// %%
string str = "Supercalifragilisticexpialidocious";

    string value = "ice";
    Boolean result = str.Contains(value);
    
        Console.WriteLine(result);
// Out:
// True

// %%
string firstword = "Supercalifragilisticexpialidocious";
string secondword = "Honorificabilitudinitatibus";
string thirdword = "Bababadalgharaghtakamminarronnkonn";

    Console.WriteLine(firstword.Length);
        Console.WriteLine(secondword.Length);
            Console.WriteLine(thirdword.Length);
// Out:
// 34
// 27
// 34

// %%
string[] composers = {"Berlioz", "Borodin", "Brian", "Bartok", "Bellini", "Buxtehude", "Bernstein"};
    Array.Sort(composers);
        foreach (string a in composers)
        
         Console.WriteLine(a);
// Out:
// Bartok
// Bellini
// Berlioz
// Bernstein
// Borodin
// Brian
// Buxtehude

// %% [markdown]
// Question 3. C#

// %%
double s, area;
double a, b, c;

    Console.WriteLine("Enter side #1");
    a = double.Parse(Console.ReadLine());
    Console.WriteLine("Enter side #2");
    b = double.Parse(Console.ReadLine());
    Console.WriteLine("Enter side #3");
    c = double.Parse(Console.ReadLine());

    s = (a + b + c) / 2;
    area = Math.Sqrt(s * ( s - a) * (s - b) * (s - c));

    Console.WriteLine("Area = {0}", area);
// Out:
// Enter side #1
// Unhandled Exception
// Value cannot be null. (Parameter 's')
//    at System.Double.Parse(String s)
//    at Submission#74.<<Initialize>>d__0.MoveNext()
// --- End of stack trace from previous location where exception was thrown ---
//    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

// %% [markdown]
// Question 4. C#

// %%
int[] arr1 = new int [10];
int[] arr2 = new int [10];
int[] arr3 = new int [10];
int i,j=0,k=0,n;

    Console.Write("Separate odd and even integers in separate arrays: ");
    Console.Write(" ");
    Console.Write("Input number of elements to be stored :");
    n = Convert.ToInt32(Console.ReadLine());
    Console.Write("Input {0} elements in the array : ",n);
    for(i=0;i<n;i++)
    
        Console.Write("element - {0} : ",i);
        arr1{i}=Convert.ToInt32(Console.ReadLine());
        
    for(i=0;i<n;i++);
    
    if (arr1{i}%2 ==0);
    
        arr2{j} = arr{i};
        j++;
        
    else
    
        arr3{k} = arr1{i};
        k==;
        
    Console.Write("The even elements are : ");
    for(i=0;i<j;i++);
    
    Console.Write("{0} ",arr2[i]);
    
    Console.Write(The odd elements are : ");
    for(i=0,i<k,i++);
    
    Console.Write("{0} ", arr3[i]);
    
    Console.Write("\n\n");
    
//https://stackoverflow.com/questions/47255485/c-sharp-heron-triangles
// Out:
// (14,13): error CS1002: ; expected
// (14,15): error CS1002: ; expected
// (14,16): error CS1525: Invalid expression term '='
// (18,13): error CS1026: ) expected
// (18,15): error CS1002: ; expected
// (18,16): error CS1525: Invalid expression term '%'
// (18,22): error CS1002: ; expected
// (18,22): error CS7017: Member definition, statement, or end-of-file expected
// (20,13): error CS1002: ; expected
// (20,15): error CS1002: ; expected
// (20,17): error CS1525: Invalid expression term '='
// (20,22): error CS1002: ; expected
// (20,24): error CS1002: ; expected
// (21,13): error CS8641: 'else' cannot start a statement.
// (21,13): error CS1003: Syntax error, '(' expected
// (21,13): error CS1525: Invalid expression term 'else'
// (21,13): error CS1026: ) expected
// (21,13): error CS1525: Invalid expression term 'else'
// (21,13): error CS1002: ; expected
// (25,13): error CS1002: ; expected
// (25,15): error CS1002: ; expected
// (25,17): error CS1525: Invalid expression term '='
// (25,23): error CS1002: ; expected
// (25,25): error CS1002: ; expected
// (26,12): error CS1525: Invalid expression term ';'
// (33,23): error CS1003: Syntax error, ',' expected
// (33,27): error CS1003: Syntax error, ',' expected
// (33,36): error CS1003: Syntax error, ',' expected
// (33,42): error CS1010: Newline in constant
// (33,45): error CS1026: ) expected
// (33,45): error CS1002: ; expected
// (34,20): error CS1002: ; expected
// (34,20): error CS1525: Invalid expression term ')'
// (34,20): error CS1002: ; expected

// %% [markdown]
// Question 5. C#
